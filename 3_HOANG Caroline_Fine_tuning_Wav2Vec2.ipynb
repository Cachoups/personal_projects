# %% [markdown]
# # Introduction
#
# The goal of this project is to explore the pretrained model for ASR, Wav2Vec2 which uses transformer network. We use short sentences to train and test our model for 2 languages : English and Spanish. We use different kind of approach. For the English one, we will use the Timit data that contains hours of speech and the Spanish one, which only contains around 10 min of speech. We want to see the limit between those 2 approaches and we want to test how good those models are. We will as well see how we can improve those models. In order to evaluate our model we need to use a metric and we chose the"Word error rate" (WER) metric.
#
# You can find the datasets used on the following link : https://drive.google.com/drive/folders/1LnBKW9yf-r_iueT4ylM96a-3fP4h0X_2?usp=sharing

# %% [markdown]
# # ***Fine tuning Wav2Vec2 for Spanish***

# %% [markdown]
# ## Model
#
# The model used in the former part of this notebook was pretrained on exclusively english data (using *facebook/wav2vec2-base*). Therefore, we could not use the same one if we wanted to have a chance to obtain good results. We used the pretrained model *facebook/wav2vec2-xls-r-300m*, which is a multinlingual pretrained model for speech. It is pretrained on 436k hours of unlabeled speech and uses the wav2vec 2.0 objective, in 128 languages.
#
# ## Data
#
# We created on our own spanish dataset, that can be found in the archive spanish.zip in the shared folder ASP. There are two folders : the *train* folder contains audio for training, and the *test* folder contains the audio for testing. The metadata file contains the metadata needed to create the dataset (file name and transcription), plus some additional data (accent, speaker_id, ...).
#
# **Training** : We took sentences from spanish texts and used a *text to speech* technologie to create the audio. We took the sentences from https://lingua.com/spanish/reading/ and used the website https://ttsfree.com/ to obtain the audio. On this last website, it is possible to choose the accent when generating the audio. Thus, in our training set, we have accents from Spain, Uruguay, Porto Rico, Venezuela, Peru, Mexico, Cuba, Colombia, and Argentina. We then converted the audio to have a wav format with a sampling frequence of 16kHz.
#
# **Testing** : For the test data, we did our recordings, reading some passages from texts. The accent is therefore a "French" accent.
#
#
# ## Code
#
# The code is for most part the same. The main differences are the data itself and the way the dataset is created.

# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install -U transformers==4.24.0  # 4.17.0
# !pip install jiwer

# %%capture
# !apt install git-lfs
# !pip install evaluate

import json
import random
import re
from pathlib import Path

import datasets
import evaluate
import IPython.display as ipd
import numpy as np
import pandas as pd
import torch
import transformers
from dataclasses import dataclass, field
from datasets import ClassLabel, load_dataset  # load_metric
from huggingface_hub import notebook_login
from IPython.display import display, HTML
from transformers import (
    Trainer,
    TrainingArguments,
    Wav2Vec2CTCTokenizer,
    Wav2Vec2FeatureExtractor,
    Wav2Vec2ForCTC,
    Wav2Vec2Processor,
)
from typing import Any, Dict, List, Optional, Union

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets==1.18.3
#   Downloading datasets-1.18.3-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (2022.11.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (3.8.3)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 10.7 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (1.21.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (2.25.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (21.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (4.64.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets==1.18.3) (9.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (6.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets==1.18.3) (22.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (3.8.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.3) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets==1.18.3) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets==1.18.3) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets==1.18.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets==1.18.3) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.18.3) (1.15.0)
# Installing collected packages: xxhash, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-1.18.3 huggingface-hub-0.11.1 multiprocess-0.70.14 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.24.0
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (2.25.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (0.11.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (3.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==4.24.0) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers==4.24.0) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.24.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.24.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.24.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.24.0) (2.10)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.2 transformers-4.24.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting levenshtein==0.20.2
#   Downloading Levenshtein-0.20.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.3 MB/s eta 0:00:00
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 47.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, levenshtein, jiwer
# Successfully installed jiwer-2.5.1 levenshtein-0.20.2 rapidfuzz-2.13.7
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from evaluate) (0.70.14)
# Collecting datasets>=2.0.0
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from evaluate) (1.21.6)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (0.11.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from evaluate) (4.64.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from evaluate) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from evaluate) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->evaluate) (1.24.3)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: urllib3, responses, datasets, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: datasets
#     Found existing installation: datasets 1.18.3
#     Uninstalling datasets-1.18.3:
#       Successfully uninstalled datasets-1.18.3
# Successfully installed datasets-2.8.0 evaluate-0.4.0 responses-0.18.0 urllib3-1.26.13
# Mounted at /content/drive

# %%
# downloading the data
#!wget http://data.deepai.org/timit.zip

# decompressing the data
from zipfile import ZipFile

with ZipFile('/content/drive/MyDrive/ASR/spanish.zip','r') as zip:
   zip.extractall()
   print('Data decompressed successfully')

# removing the .zip file after extraction to clean space
# !rm spanish.zip
# Out:
# Data decompressed successfully
# rm: cannot remove 'spanish.zip': No such file or directory

# %%
DATA = Path("./spanish").expanduser()
DATA.is_dir()
# Out:
# True

# %%
spanish_dataset = load_dataset("audiofolder", data_dir="/content/spanish")
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/20 [00:00<?, ?it/s]
# WARNING:datasets.builder:Using custom data configuration default-483c70c8d76b53ca
# Downloading and preparing dataset audiofolder/default to /root/.cache/huggingface/datasets/audiofolder/default-483c70c8d76b53ca/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc...
# Downloading data files:   0%|          | 0/73 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Downloading data files:   0%|          | 0/21 [00:00<?, ?it/s]
# Downloading data files: 0it [00:00, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset audiofolder downloaded and prepared to /root/.cache/huggingface/datasets/audiofolder/default-483c70c8d76b53ca/0.0.0/6cbdd16f8688354c63b4e2a36e1585d05de285023ee6443ffd71c4182055c0fc. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
spanish_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'test_or_train', 'speaker_id', 'accent', 'text'],
#         num_rows: 72
#     })
#     test: Dataset({
#         features: ['audio', 'test_or_train', 'speaker_id', 'accent', 'text'],
#         num_rows: 20
#     })
# })

# %%
spanish_dataset = spanish_dataset.remove_columns(
    [
        "accent",
        "speaker_id",
        "test_or_train",
    ]
)

# %%
from IPython.display import display

def show_random_elements(dataset, num_examples=3):
    assert num_examples <= len(
        dataset
    ), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset) - 1)
        while pick in picks:
            pick = random.randint(0, len(dataset) - 1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(spanish_dataset["train"].remove_columns(["audio"]), num_examples=3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Mi nombre es Laura y mi familia es muy divertida. Mi abuela Rocío cocina delicioso, por lo que nos encanta comer y hacer sobremesa. Mi abuelo Julio encuentra monedas detrás de las orejas de las personas, no sé por qué se queja sobre la vida de pensionado.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>El armario está situado a la derecha del escritorio y tiene mucho espacio para poder colocar la ropa. Me gusta tenerla bien doblada y organizada.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>También me animó a tocar el piano para mejorar la coordinación entre mi cerebro y mi cuerpo, mi capacidad cognitiva, perseverancia y disciplina.</td>
#     </tr>
#   </tbody>
# </table>

# %%
chars_to_ignore_regex = '[\,\?\¿\.\…\!\¡\-\;\:"]'


def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, "", batch["text"]).lower() + " "
    return batch

# %%
spanish_dataset = spanish_dataset.map(remove_special_characters)
# Out:
#   0%|          | 0/72 [00:00<?, ?ex/s]
#   0%|          | 0/20 [00:00<?, ?ex/s]

# %%
show_random_elements(spanish_dataset["train"].remove_columns(["audio"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>poco antes de cerrar la tienda llega un hombre muy apurado porque debe hacer un viaje a finlandia y no tiene ropa abrigada</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>hace un mes que he hecho la reserva de la habitación y estoy encantado la habitación es de tamaño mediano tiene mucha luz y una gran ventana tengo una cama grande y una gran caja fuerte</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>encima del escritorio tengo un estante donde almaceno todos mis libros y también otros objetos que me gustan y decoran la habitación como un cuadro o una flor de tela de bonitos colores</td>
#     </tr>
#   </tbody>
# </table>

# %%
def extract_all_chars(batch):
    all_text = " ".join(batch["text"])
    vocab = list(set(all_text))
    return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = spanish_dataset.map(
    extract_all_chars,
    batched=True,
    batch_size=-1,
    keep_in_memory=True,
    remove_columns=spanish_dataset.column_names["train"],
)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0])) #  | set(vocabs["test"]["vocab"][0]
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'ñ': 0,
#  'u': 1,
#  'k': 2,
#  's': 3,
#  'ú': 4,
#  'n': 5,
#  'j': 6,
#  'y': 7,
#  'á': 8,
#  'm': 9,
#  '2': 10,
#  'b': 11,
#  'i': 12,
#  'p': 13,
#  'v': 14,
#  'q': 15,
#  'e': 16,
#  'z': 17,
#  'h': 18,
#  'ó': 19,
#  'r': 20,
#  't': 21,
#  'l': 22,
#  'é': 23,
#  'a': 24,
#  '1': 25,
#  'd': 26,
#  'g': 27,
#  'c': 28,
#  ' ': 29,
#  'o': 30,
#  'f': 31,
#  'x': 32,
#  'í': 33,
#  '0': 34}

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)

with open("vocab.json", "w") as vocab_file:
    json.dump(vocab_dict, vocab_file)

spanish_tokenizer = Wav2Vec2CTCTokenizer(
    "./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|"
)

# %%
spanish_repo_name = "wav2vec2-base-spanish-demo-google-colab"
spanish_repo_name2 = "Cachoups/wav2vec2-base-spanish-demo-google-colab"

# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
spanish_tokenizer.push_to_hub(spanish_repo_name)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab/commit/b639b3257f72174d756cb7ccd4d4f58bd0e0d6e7', commit_message='Upload tokenizer', commit_description='', oid='b639b3257f72174d756cb7ccd4d4f58bd0e0d6e7', pr_url=None, pr_revision=None, pr_num=None)

# %%
feature_extractor = Wav2Vec2FeatureExtractor(
    feature_size=1,
    sampling_rate=16000,
    padding_value=0.0,
    do_normalize=True,
    return_attention_mask=False,
)

# %%
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=spanish_tokenizer)

# %%
spanish_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['audio', 'text'],
#         num_rows: 72
#     })
#     test: Dataset({
#         features: ['audio', 'text'],
#         num_rows: 20
#     })
# })

# %% [markdown]
# ### Preprocess Data

# %%
# verifying that the audio was correctly loaded
rand_int = random.randint(0, len(spanish_dataset["train"]))

print(spanish_dataset["train"][rand_int]["text"])
ipd.Audio(
    data=np.asarray(spanish_dataset["train"][rand_int]["audio"]["array"]),
    autoplay=True,
    rate=16000,
)
# Out:
# así que comencé a probar otros deportes como el basquetbol y el tenis
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(spanish_dataset["train"]))

print("Target text:", spanish_dataset["train"][rand_int]["text"])
print(
    "Input array shape:", np.asarray(spanish_dataset["train"][rand_int]["audio"]["array"]).shape
)
print("Sampling rate:", spanish_dataset["train"][rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: así que comencé a probar otros deportes como el basquetbol y el tenis
# Input array shape: (74880,)
# Sampling rate: 16000

# %%
for i in range(72):
  if (spanish_dataset['train'][i]['audio']['sampling_rate'] != 16000):
    print(spanish_dataset['train'][i])

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(
          audio["array"], sampling_rate=audio["sampling_rate"]
      ).input_values[0]
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
spanish_dataset = spanish_dataset.map(
    prepare_dataset, remove_columns=spanish_dataset.column_names["train"], num_proc=4
)
# Out:
# #1:   0%|          | 0/18 [00:00<?, ?ex/s]
# #2:   0%|          | 0/18 [00:00<?, ?ex/s]
# #0:   0%|          | 0/18 [00:00<?, ?ex/s]
# #3:   0%|          | 0/18 [00:00<?, ?ex/s]
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# #3:   0%|          | 0/5 [00:00<?, ?ex/s]
# #1:   0%|          | 0/5 [00:00<?, ?ex/s]
# #0:   0%|          | 0/5 [00:00<?, ?ex/s]
# #2:   0%|          | 0/5 [00:00<?, ?ex/s]
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(

# %%
#max_input_length_in_sec = 4.0
#spanish_dataset["train"] = spanish_dataset["train"].filter(
#    lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate,
#    input_columns=["input_length"],
#)

# %% [markdown]
# ## Training & Evaluation

# %%
@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str`,
                 or :class:`~transformers.tokenization_utils_base.PaddingStrategy`,
                 `optional`,
                 defaults to :obj:`True`):
            Select a strategy to pad the returned sequences
            (according to the model's padding side and padding index) among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch
                (or no padding if only a single sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument
                :obj:`max_length` or to the maximum acceptable input length for the model
                if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding
                (i.e., can output a batch with sequences of different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [
            {"input_values": feature["input_values"]} for feature in features
        ]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = evaluate.load("wer")
# Out:
# Downloading builder script:   0%|          | 0.00/4.49k [00:00<?, ?B/s]

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-xls-r-300m",
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer),
)
# Out:
# Downloading:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.27G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-xls-r-300m were not used when initializing Wav2Vec2ForCTC: ['project_hid.bias', 'project_q.bias', 'quantizer.codevectors', 'project_q.weight', 'quantizer.weight_proj.bias', 'project_hid.weight', 'quantizer.weight_proj.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-xls-r-300m and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
model.freeze_feature_encoder() #maybe unfreeze if bad results

# %%
spanish_training_args = TrainingArguments(
    output_dir=spanish_repo_name2,
    group_by_length=True,
    per_device_train_batch_size=4, #reducing batch_size was necessary to remove the "out of memory" error
    evaluation_strategy="steps",
    num_train_epochs=100,
    # fp16=True,    # For GPU
    gradient_checkpointing=True,
    save_steps=10,
    eval_steps=10,
    logging_steps=10,
    learning_rate=1e-4,
    weight_decay=0.005,
    warmup_steps=5,
    save_total_limit=2,
    push_to_hub=True
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
spanish_dataset["train"]
# Out:
# Dataset({
#     features: ['input_values', 'input_length', 'labels'],
#     num_rows: 72
# })

# %%
spanish_trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=spanish_training_args,
    compute_metrics=compute_metrics,
    train_dataset=spanish_dataset["train"],
    eval_dataset=spanish_dataset["test"],
    tokenizer=processor.feature_extractor,
)
# Out:
# /content/Loelia/wav2vec2-base-spanish-demo-google-colab is already a clone of https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/Loelia/wav2vec2-base-spanish-demo-google-colab is already a clone of https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
spanish_trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 72
#   Num Epochs = 100
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1800
#   Number of trainable parameters = 311266469
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
#     <div>
#
#       <progress value='1800' max='1800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1800/1800 2:20:25, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.039900</td>
#       <td>3.679806</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.958600</td>
#       <td>3.797618</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.966200</td>
#       <td>3.666707</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.978100</td>
#       <td>3.400784</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.926100</td>
#       <td>3.255877</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.035800</td>
#       <td>3.198736</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.932100</td>
#       <td>3.600662</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.991600</td>
#       <td>3.332069</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.921900</td>
#       <td>3.389026</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.899300</td>
#       <td>3.162867</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2.910300</td>
#       <td>3.222908</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>2.931100</td>
#       <td>3.071696</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>2.943800</td>
#       <td>3.139804</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>2.883700</td>
#       <td>3.109406</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.917900</td>
#       <td>3.170171</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>2.887800</td>
#       <td>3.094573</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>2.886900</td>
#       <td>3.008276</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>2.880600</td>
#       <td>3.084746</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>2.907800</td>
#       <td>3.143420</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.902900</td>
#       <td>3.066079</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.867400</td>
#       <td>3.037852</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>2.879300</td>
#       <td>3.160396</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.888900</td>
#       <td>3.033581</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>2.875400</td>
#       <td>2.969070</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.882600</td>
#       <td>3.123124</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>2.870300</td>
#       <td>3.078950</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>2.867100</td>
#       <td>3.047798</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>2.851500</td>
#       <td>3.028018</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>2.886900</td>
#       <td>2.988766</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.875100</td>
#       <td>3.138201</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>2.882200</td>
#       <td>2.960010</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>2.865400</td>
#       <td>2.965165</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>2.853500</td>
#       <td>2.989871</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>2.875800</td>
#       <td>2.950871</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.873700</td>
#       <td>2.964525</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>2.871700</td>
#       <td>3.027625</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>2.870500</td>
#       <td>3.011786</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>2.859200</td>
#       <td>2.953574</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>2.880700</td>
#       <td>2.958882</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.830800</td>
#       <td>2.948730</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>2.797000</td>
#       <td>2.895073</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>2.839600</td>
#       <td>2.950576</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>2.827000</td>
#       <td>3.175747</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>2.710300</td>
#       <td>2.969312</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>2.661900</td>
#       <td>2.756994</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>2.516800</td>
#       <td>2.712536</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>2.427200</td>
#       <td>2.712966</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>2.332500</td>
#       <td>2.571133</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>2.181500</td>
#       <td>2.398445</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.965900</td>
#       <td>2.144572</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.820400</td>
#       <td>1.983981</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.570900</td>
#       <td>1.875530</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>1.400100</td>
#       <td>1.707522</td>
#       <td>0.995327</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>1.346000</td>
#       <td>1.543922</td>
#       <td>0.981308</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.175600</td>
#       <td>1.542717</td>
#       <td>0.934579</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.113800</td>
#       <td>1.488046</td>
#       <td>0.901869</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.058500</td>
#       <td>1.501284</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.921600</td>
#       <td>1.509071</td>
#       <td>0.967290</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.082600</td>
#       <td>1.839138</td>
#       <td>1.285047</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.848200</td>
#       <td>1.417297</td>
#       <td>0.915888</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.828600</td>
#       <td>1.297261</td>
#       <td>0.957944</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.946400</td>
#       <td>1.257379</td>
#       <td>0.901869</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.665400</td>
#       <td>1.211025</td>
#       <td>0.845794</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.811800</td>
#       <td>1.402293</td>
#       <td>1.042056</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.817000</td>
#       <td>1.235096</td>
#       <td>0.915888</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.580500</td>
#       <td>1.316757</td>
#       <td>0.985981</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.729400</td>
#       <td>1.233711</td>
#       <td>0.850467</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.667900</td>
#       <td>1.326381</td>
#       <td>0.953271</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.569300</td>
#       <td>1.324351</td>
#       <td>0.995327</td>
#     </tr>
#     <tr>
#       <td>700</td
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-10
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-10/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-10/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-10/preprocessor_config.json
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/preprocessor_config.json
# Several commits (3) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (3) will be pushed upstream.
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-20
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-20/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-20/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-20/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-30
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-30/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-30/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-30/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-10] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-40
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-40/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-40/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-40/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-20] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-50
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-50/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-50/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-50/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-30] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-60
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-60/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-60/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-60/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-40] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-70
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-70/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-70/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-70/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-50] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-80
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-80/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-80/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-80/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-60] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-90
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-90/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-90/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-90/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-70] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-100
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-100/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-100/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-100/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-80] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-110
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-110/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-110/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-110/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-90] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-120
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-120/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-120/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-120/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-100] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-130
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-130/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-130/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-130/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-110] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-140
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-140/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-140/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-140/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-120] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-150
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-150/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-150/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-150/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-130] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-160
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-160/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-160/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-160/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-140] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-150] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-160] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-190
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-190/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-190/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-190/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-170] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-200
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-200/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-200/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-200/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-180] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-210
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-210/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-210/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-210/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-190] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-220
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-220/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-220/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-220/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-200] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-230
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-230/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-230/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-230/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-210] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-240
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-240/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-240/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-240/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-220] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-250
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-250/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-250/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-250/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-230] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-260
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-260/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-260/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-260/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-240] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-270
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-270/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-270/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-270/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-250] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-280
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-280/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-280/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-280/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-260] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-290
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-290/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-290/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-290/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-270] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-300
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-300/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-300/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-300/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-280] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-310
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-310/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-310/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-310/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-290] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-320
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-320/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-320/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-320/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-300] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ...
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1680
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1680/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1680/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1680/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1660] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1690
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1690/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1690/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1690/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1670] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1700
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1700/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1700/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1700/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1680] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1710
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1710/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1710/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1710/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1690] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1720
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1720/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1720/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1720/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1700] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1730
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1730/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1730/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1730/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1710] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1740
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1740/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1740/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1740/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1720] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1750
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1750/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1750/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1750/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1730] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1760
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1760/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1760/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1760/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1740] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1770
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1770/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1770/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1770/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1750] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1780
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1780/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1780/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1780/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1760] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1790
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1790/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1790/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1790/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1770] due to args.save_total_limit
# /usr/local/lib/python3.8/dist-packages/transformers/models/wav2vec2/processing_wav2vec2.py:154: UserWarning: `as_target_processor` is deprecated and will be removed in v5 of Transformers. You can process your labels by using the argument `text` of the regular `__call__` method (either in the same call as your audio inputs, or in a separate call.
#   warnings.warn(
# The following columns in the evaluation set don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 20
#   Batch size = 8
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1800
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1800/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1800/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1800/preprocessor_config.json
# Deleting older checkpoint [Loelia/wav2vec2-base-spanish-demo-google-colab/checkpoint-1780] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1800, training_loss=1.0308863363001082, metrics={'train_runtime': 8431.5251, 'train_samples_per_second': 0.854, 'train_steps_per_second': 0.213, 'total_flos': 2.6590790589323187e+18, 'train_loss': 1.0308863363001082, 'epoch': 100.0})

# %%
spanish_trainer.push_to_hub()
# Out:
# Saving model checkpoint to Loelia/wav2vec2-base-spanish-demo-google-colab
# Configuration saved in Loelia/wav2vec2-base-spanish-demo-google-colab/config.json
# Model weights saved in Loelia/wav2vec2-base-spanish-demo-google-colab/pytorch_model.bin
# Feature extractor saved in Loelia/wav2vec2-base-spanish-demo-google-colab/preprocessor_config.json
# Several commits (4) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (4) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          | 3.30k/1.18G [00:00<?, ?B/s]
# Upload file runs/Jan05_14-54-43_304d54d1c2de/events.out.tfevents.1672930497.304d54d1c2de.232.6:   4%|3        …
# remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab
#    b639b32..dbc29d3  main -> main
#
# WARNING:huggingface_hub.repository:remote: Scanning LFS files for validity, may be slow...
# remote: LFS file scan complete.
# To https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab
#    b639b32..dbc29d3  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Automatic Speech Recognition', 'type': 'automatic-speech-recognition'}, 'metrics': [{'name': 'Wer', 'type': 'wer', 'value': 0.7383177570093458}]}
# To https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab
#    dbc29d3..9795233  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab
#    dbc29d3..9795233  main -> main
# 'https://huggingface.co/Cachoups/wav2vec2-base-spanish-demo-google-colab/commit/dbc29d3967d7cb6a5ad50646ee3d1792f0c08556'

# %%
from transformers import AutoModelForCTC, Wav2Vec2Processor

# %% [markdown]
# ### *Remarks* :
#
# - We first trained with a smaller number of epochs (5) but had random output of letters as prediction. We increased the number to 30, but then had no prediction at all (a blank string). In both cases, we therefore had 100% WER. Only when we hit around 100 epochs did we have a real result, with which we could work. We also see that the WER first remains constant with a value of 100% and begin to fall after step 520.
#
# - In the end, we have a loss around 0.1, but a validation loss stagnating at 1.2. We must have overtrained the model, but given the time taken to train it, and the fact that the validation loss did not rise again, we kept this one to do the tests.

# %% [markdown]
# ### Evaluate

# %%
processor = Wav2Vec2Processor.from_pretrained(
    "Cachoups/wav2vec2-base-spanish-demo-google-colab"
)
# Out:
# Downloading:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/236 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "Cachoups/wav2vec2-base-spanish-demo-google-colab"
).cuda()

# %%
def map_to_result(batch):
    with torch.no_grad():
        input_values = torch.tensor(batch["input_values"], device = "cuda").unsqueeze(0)
        logits = model(input_values).logits

    pred_ids = torch.argmax(logits, dim=-1)
    batch["pred_str"] = processor.batch_decode(pred_ids)[0]
    batch["text"] = processor.decode(batch["labels"], group_tokens=False)

    return batch

# %%
def prepare_dataset_test(batch):
    audio = batch["input_values"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(
        audio["array"], sampling_rate=audio["sampling_rate"]
    ).input_values[0]
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
# PRED FOR NORMAL TEST
results = spanish_dataset["test"].map(map_to_result, remove_columns=spanish_dataset["test"].column_names)
# Out:
#   0%|          | 0/20 [00:00<?, ?ex/s]

# %%
print(
    "Test WER: {:.3f}".format(
        wer_metric.compute(predictions=results["pred_str"], references=results["text"])
    )
)
# Out:
# Test WER: 0.668

# %%
show_random_elements(results)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>los liblo asso s son me jugaes que la tere ibición</td>
#       <td>los libros son mejores que la televisión</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>todos emos ouido ablar de la clostro fobia</td>
#       <td>todos hemos oído hablar de la claustrofobia</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>po ejemplo los ñiños no soportan la osculidado</td>
#       <td>por ejemplo los niños no soportan la oscuridad</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The results are quite bad. At least, it seems the model can recognize the sounds, but it seems unable to recognize and form the right words from those sounds. However, as we used our own recordings for the tests, it could partially be due to the accent - French - that we didn't use in the training, or other reasons detailed earlier in the english part.

# %% [markdown]
# # Conclusion
# To conclude, for English language, the model trained with the pre-trained from Facebook can have good results when the speaker talks clearly and well without noise involved. A clipped sound doesn't affect consequently the quality of prediction. For Spanish language, because of the lack of data, we have to overtrain our model to have a decent result. We could have added white noise or clipped version of the audio to first make the model better and secondly to have more audio.
